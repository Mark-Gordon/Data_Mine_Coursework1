# %%
import pandas as pd
from numpy import loadtxt

# %%
df = pd.read_csv("fer2018PixelSplitRandomize.csv");
lines = loadtxt("10pixelscombinedinorder.txt", comments="#", delimiter=",", unpack=False)
index_df = df["emotion"]
df = df.drop(["emotion"], axis=1)

# %%
thislist = []
def myfunc(a):
    for x in range(len(a)):
         thislist.append("pixel" + str(lines[x].astype(int)))

# %%
myfunc(lines)

# %%
df = df[thislist]
df = df.loc[:,~df.columns.duplicated()]
df.insert(0, "emotion", index_df)
df = df.set_index("emotion")

# %%
df.to_csv("fer2018PixelSplitRandomizeMinMaxTop10.csv");

# %%
df.head()
# Out:
#          pixel11  pixel12  pixel13  pixel14  pixel23  pixel24  pixel25  \
# emotion
# 5            118       97       77       61       23       20       17
# 0            242      250      164       63       53       61       49
# 6             19       10       62      110      157      158      159
# 6              5       10       47       76      126      133      130
# 5             64       63       79       53       59       76       95
#
#          pixel26  pixel27  pixel30    ...      pixel1848  pixel1849  \
# emotion                               ...
# 5             14       11        7    ...            171        170
# 0             41       45       38    ...            153        152
# 6            159      158      158    ...            114        106
# 6            130      126       99    ...            144        145
# 5            105      116      109    ...             13         11
#
#          pixel1850  pixel1896  pixel1897  pixel1898  pixel1944  pixel1945  \
# emotion
# 5              170        170        170        170        170        170
# 0              134        162        149        112        158        136
# 6              104         74         66         75        112        109
# 6              153        106        109        121        120        119
# 5               10         12         13         13         15         17
#
#          pixel1992  pixel1993
# emotion
# 5              170        170
# 0              153        106
# 6              130        124
# 6               92         95
# 5               27         33
#
# [5 rows x 69 columns]
