# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("fer2018.csv");

# %%
outputDf = df["pixels"].str.split(' ', expand=True).rename(columns = lambda x: "pixel"+str(x+1))
outputDf.head()
# Out:
#   pixel1 pixel2 pixel3 pixel4 pixel5 pixel6 pixel7 pixel8 pixel9 pixel10  \
# 0     70     80     82     72     58     58     60     63     54      58
# 1    151    150    147    155    148    133    111    140    170     174
# 2    231    212    156    164    174    138    161    173    182     200
# 3     24     32     36     30     32     23     19     20     30      41
# 4      4      0      0      0      0      0      0      0      0       0
#
#      ...    pixel2295 pixel2296 pixel2297 pixel2298 pixel2299 pixel2300  \
# 0    ...          159       182       183       136       106       116
# 1    ...          105       108        95       108       102        67
# 2    ...          104       138       152       122       114       101
# 3    ...          174       126       132       132       133       136
# 4    ...           12        34        31        31        31        27
#
#   pixel2301 pixel2302 pixel2303 pixel2304
# 0        95       106       109        82
# ...

# %%
outputDf.insert(0, "emotion", df["emotion"])

# %%
outputDf.head(5)
# Out:
#    emotion pixel1 pixel2 pixel3 pixel4 pixel5 pixel6 pixel7 pixel8 pixel9  \
# 0        0     70     80     82     72     58     58     60     63     54
# 1        0    151    150    147    155    148    133    111    140    170
# 2        2    231    212    156    164    174    138    161    173    182
# 3        4     24     32     36     30     32     23     19     20     30
# 4        6      4      0      0      0      0      0      0      0      0
#
#      ...    pixel2295 pixel2296 pixel2297 pixel2298 pixel2299 pixel2300  \
# 0    ...          159       182       183       136       106       116
# 1    ...          105       108        95       108       102        67
# 2    ...          104       138       152       122       114       101
# 3    ...          174       126       132       132       133       136
# 4    ...           12        34        31        31        31        27
#
#   pixel2301 pixel2302 pixel2303 pixel2304
# 0        95       106       109        82
# ...

# %%
outputDf = outputDf.set_index("emotion")

# %%
outputDf.to_csv("fer2018PixelSplit.csv");
