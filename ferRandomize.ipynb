# %%
import pandas as pd

# %%
df = pd.read_csv("fer2018angryPixelSplit.csv");

# %%
df.head(5)
# Out:
#    emotion  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0        1      70      80      82      72      58      58      60      63
# 1        1     151     150     147     155     148     133     111     140
# 2        0     231     212     156     164     174     138     161     173
# 3        0      24      32      36      30      32      23      19      20
# 4        0       4       0       0       0       0       0       0       0
#
#    pixel9    ...      pixel2295  pixel2296  pixel2297  pixel2298  pixel2299  \
# 0      54    ...            159        182        183        136        106
# 1     170    ...            105        108         95        108        102
# 2     182    ...            104        138        152        122        114
# 3      30    ...            174        126        132        132        133
# 4       0    ...             12         34         31         31         31
#
#    pixel2300  pixel2301  pixel2302  pixel2303  pixel2304
# ...

# %%
df = df.sample(frac=1).reset_index(drop=True)
df = df.set_index("emotion")

# %%
df.head(5)
# Out:
#          pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# emotion
# 0            41      90      99     104     110     122     126     121
# 0           246     245     244     245     246     244     245     247
# 1            82      78      78      67      76      86      74      77
# 0            95      86      91      85      81      83      88      89
# 0           151     153     155     156     155     157     172     191
#
#          pixel9  pixel10    ...      pixel2295  pixel2296  pixel2297  \
# emotion                     ...
# 0           123      130    ...              0          0          0
# 0           245      239    ...             53        125        158
# 1            93       76    ...             48         46         26
# 0            90       88    ...            246        213        129
# 0           203      210    ...             76        132         92
#
# ...

# %%
df.to_csv("fer2018angryPixelSplitRandomize.csv");
