# %%
import pandas as pd

# %%
df = pd.read_csv("fer2018PixelSplit.csv");

# %%
df.head(5)
# Out:
#    emotion  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0        0      70      80      82      72      58      58      60      63
# 1        0     151     150     147     155     148     133     111     140
# 2        2     231     212     156     164     174     138     161     173
# 3        4      24      32      36      30      32      23      19      20
# 4        6       4       0       0       0       0       0       0       0
#
#    pixel9    ...      pixel2295  pixel2296  pixel2297  pixel2298  pixel2299  \
# 0      54    ...            159        182        183        136        106
# 1     170    ...            105        108         95        108        102
# 2     182    ...            104        138        152        122        114
# 3      30    ...            174        126        132        132        133
# 4       0    ...             12         34         31         31         31
#
#    pixel2300  pixel2301  pixel2302  pixel2303  pixel2304
# ...

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head(5)
# Out:
#    emotion  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0        2     159     159     159     160     163     168      74      51
# 1        0     140      82      50      76     101      80      84     114
# 2        6      63      44      30      45      47      39      28      18
# 3        6     255     255     255     253     255     216     171     174
# 4        3      58      64      63      33      28      27      29      28
#
#    pixel9    ...      pixel2295  pixel2296  pixel2297  pixel2298  pixel2299  \
# 0      59    ...            123         48          8         12         19
# 1      84    ...             41         31         34         36         29
# 2      11    ...             49         28         62         62         60
# 3     182    ...            144        144        142        137        120
# 4      29    ...             62         41         34         33         34
#
#    pixel2300  pixel2301  pixel2302  pixel2303  pixel2304
# ...

# %%
outputDf.to_csv("fer2018PixelSplitRandomize.csv");
